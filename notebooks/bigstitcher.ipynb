# %%
import os
import subprocess
import argparse
from PIL import Image

# %%
from stapl3d.preprocessing import stitching

# %%
image_in = "../data/data8channels-001.czi"

# %%
parameter_file = "../prueba.yaml"

# %%
dataset = "prueba_"

# %%
stitch3r = stitching.Stitch3r(image_in, parameter_file, prefix=dataset)
stitch3r.FIJI = 'fiji/Fiji.app/ImageJ-win64.exe'
stitch3r.run()

# %%
# !python STAPL3D/stapl3d/preprocessing/stitching.py --image_in docker_vm_lif_test/04_unmix/lif/test_latest/images --parameter_file prueba.yaml
