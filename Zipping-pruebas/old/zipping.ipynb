# %%
# GUARDADO
from zipper_owntry import Zipp3r

# %%
image_in = '/app/data/data3channelsTIFF.tif'

# %%
zipper = Zipp3r(image_in)

# Create a dictionary containing information on all blocks
zipper.set_block_slices(
    image_shape=[137,6552,6552],
    blocksize=[137,3276,3276],
    margins=[0,100,100]
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_74/2591290637.py in ?()
# ----> 1 zipper = Zipp3r(image_in)
#       2
#       3 # Create a dictionary containing information on all blocks
#       4 zipper.set_block_slices(
#
# /app/data/Zipping-pruebas/old/zipper_owntry.py in ?(self, image_path)
#      40         ### 3. From a Excel with the images and their respective positions
#      41         self.image_path = Path(image_path)
#      42         self.image_folder = self.image_path.parent
#      43         self.image_name = self.image_path.stem
# ---> 44         self.image = get_image(self.image_path)
#      45         self.ext = self.image_path.suffix
#
# /app/data/Zipping-pruebas/general_segmentation_functions/image_handling.py in ?(filepath, substruct, channel)
#     727         im = Image('{}/{}'.format(filepath, substruct), permission='r')
#     728     else:
#     729         im = Image(filepath, permission="r")
#     730     # print(im.path)
# --> 731     im.load(channel=channel)
#     732     if im.image is None:
#     733         sys.exit("Image was not loaded correctly. Exiting...")
#     734     if im.format==".ims":
#
# /app/data/Zipping-pruebas/general_segmentation_functions/image_handling.py in ?(self, substruct, channel)
#      55             loader=image_loaders[self.format]
#      56         except:
#      57             print("No loader for {} exists yet".format(self.format))
#      58         else:
# ---> 59             loader(substruct=substruct, channel=channel)
#      60
#      61         self.axlab=self.get_axlab()
#      62         return(self.image)
#
# /app/data/Zipping-pruebas/general_segmentation_functions/image_handling.py in ?(self, **kwargs)
#     588                 self.image = self.ds
#     589                 self.dims = self.ds.shape
#     590                 self.dtype = self.ds.dtype
#     591             elif tif_path.is_file():
# --> 592                 self.ds=io.imread(
#     593                     fname=tif_path
#     594                     )
#     595                 self.image=self.ds
#
# /usr/local/lib/python3.8/site-packages/skimage/io/_io.py in ?(fname, as_gray, plugin, **plugin_args)
#      49         if fname.lower().endswith(('.tiff', '.tif')):
#      50             plugin = 'tifffile'
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#      56         return img
#
# /usr/local/lib/python3.8/site-packages/skimage/io/manage_plugins.py in ?(kind, *args, **kwargs)
#     203         except IndexError:
#     204             raise RuntimeError('Could not find the plugin "%s" for %s.' %
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/skimage/io/_plugins/tifffile_plugin.py in ?(fname, **kwargs)
#      26     """
#      27     if 'img_num' in kwargs:
#      28         kwargs['key'] = kwargs.pop('img_num')
#      29
# ---> 30     return tifffile_imread(fname, **kwargs)
#
# /usr/local/lib/python3.8/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1117                     )
#    1118                     if selection is None:
#    1119                         return store
#    1120                     return zarr_selection(store, selection)
# -> 1121                 return tif.asarray(
#    1122                     key=key,
#    1123                     series=series,
#    1124                     level=level,
#
# /usr/local/lib/python3.8/site-packages/tifffile/tifffile.py in ?(self, key, series, level, squeeze, out, maxworkers)
#    4293                 # read into output
#    4294                 shape = series.get_shape(squeeze)
#    4295                 if out is not None:
#    4296                     out = create_output(out, shape, series.dtype)
# -> 4297                 result = self.filehandle.read_array(
#    4298                     typecode,
#    4299                     series.size,
#    4300                     series.dataoffset,
#
# /usr/local/lib/python3.8/site-packages/tifffile/tifffile.py in ?(self, dtype, count, offset, out)
#   14302         except AttributeError:
#   14303             result[:] = numpy.frombuffer(self._fh.read(nbytes), dtype).reshape(
#   14304                 result.shape
#   14305             )
# > 14306             n = nbytes
#   14307
#   14308         if n != nbytes:
#   14309             raise ValueError(f'failed to read {nbytes} bytes, got {n}')
#
# KeyboardInterrupt:

# %%
# Cut the image according to the block_slices
zipper.split_image()

# %%
# Segment the image
zipper.segment_image(
    seg_function=segmentation_function
)

# %%
# Calculate the zip lines that need to be extracted
zipper.set_zip_blocks()

# %%
# Resegment these zip lines
zipper.resegment_all_lines()

# %%
# Relabel all blocks and ziplines to get unique segments
zipper.relabel_blocks_and_lines()

zipper.zip_lines()
