# %%
from stapl3d import Image
from stapl3d import blocks

# %%
image_in="/Users/samdeblank/Documents/1.projects/Zipping/test_image.tiff"
parameter_file="/Users/samdeblank/Documents/1.projects/Zipping/params.yml"
block3r = blocks.Block3r(image_in, parameter_file, prefix="test_image")
splitt3r = blocks.Splitt3r(image_in, parameter_file, prefix="test_image")
splitt3r.run()
# Out:
# Running splitter:blockinfo
# Running splitter:split
